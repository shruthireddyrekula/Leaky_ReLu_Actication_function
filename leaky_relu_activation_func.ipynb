# %% [markdown]
# <a href="https://colab.research.google.com/github/shruthireddyrekula/Leaky_ReLu_Actication_function/blob/main/leaky_relu_activation_func.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Leaky ReLu addresses thge problem of zero gradients for negative value, by giving extremely small linear component of x to negative inputs

# %%
def leaky_relu(x):
  if x > 0:
    return x
  else:
    return 0.1*x

# %%
s

# %%
import matplotlib.pyplot as plt 

p1 = [x for x in range(-10, 11)]
p2 = [leaky_relu(x) for x in p1]
p3 = [relu(x) for x in p1]
plt.xlabel("x")
# plt.ylabel("leaky_relu(x)")
plt.plot(p1, p2, label="leaky_relu")
plt.plot(p1, p3, label="relu")
plt.legend()
plt.show()
